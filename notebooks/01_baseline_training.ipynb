# %% [markdown]
# # Baseline Classifier Training
#
# Train YOLOv8s-cls, EfficientNet-B0, ResNet-18 on SDNET2018 6-class.

# %% [markdown]
# ## Setup

# %%
# TODO

# %% [markdown]
# ## Data Preparation

# %%
# TODO

# %% [markdown]
# ## YOLOv8s-cls Training

# %%
# TODO

# %% [markdown]
# ## EfficientNet-B0 Training

# %%
# TODO

# %% [markdown]
# ## ResNet-18 Training

# %%
# TODO

# %% [markdown]
# ## Save Models

# %%
# TODO
