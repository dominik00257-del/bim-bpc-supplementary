# %% [markdown]
# # BIM Mapping Scalability
#
# Benchmark nearest-AABB for 15-2000 elements. Generate Table 7, Figure 4.

# %% [markdown]
# ## Synthetic IFC Generation

# %%
# TODO

# %% [markdown]
# ## Brute-Force Benchmark

# %%
# TODO

# %% [markdown]
# ## Optimised Benchmark

# %%
# TODO

# %% [markdown]
# ## Results

# %%
# TODO
