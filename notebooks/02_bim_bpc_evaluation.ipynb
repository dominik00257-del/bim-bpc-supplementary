# %% [markdown]
# # BIM-BPC Evaluation
#
# Apply BPC and rule-based correction. Generate Tables 4-5.

# %% [markdown]
# ## Load Models

# %%
# TODO

# %% [markdown]
# ## Baseline Evaluation

# %%
# TODO

# %% [markdown]
# ## BPC with Various Priors

# %%
# TODO

# %% [markdown]
# ## Rule-based Correction

# %%
# TODO

# %% [markdown]
# ## McNemar Tests

# %%
# TODO

# %% [markdown]
# ## Generate Tables

# %%
# TODO
