# %% [markdown]
# # Prior Sensitivity Analysis
#
# Vary alpha from 0 to 1. Generate Figure 3.

# %% [markdown]
# ## Setup

# %%
# TODO

# %% [markdown]
# ## SDNET2018 Alpha Sweep

# %%
# TODO

# %% [markdown]
# ## CODEBRIM Alpha Sweep

# %%
# TODO

# %% [markdown]
# ## Generate Figure 3

# %%
# TODO
